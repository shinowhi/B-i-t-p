# %% [markdown]
# <a href="https://colab.research.google.com/github/shinowhi/B-i-t-p/blob/main/bai5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

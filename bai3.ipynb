# %% [markdown]
# <a href="https://colab.research.google.com/github/shinowhi/B-i-t-p/blob/main/bai3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import folium
from geopy.geocoders import Nominatim
from folium.plugins import HeatMap
import osmnx as ox
import networkx as nx

m = folium.Map(location=[10.775, 106.700], zoom_start=13)
address =[
    "Van Hanh Mall,Ho Chi Minh City",
    "Giga Mall,Ho Chi Minh City",
    "UEH,Ho Chi Minh City",
    "Dam Sen,Ho Chi Minh City",
    "Benh Vien Cho Ray,Ho Chi Minh City",
    "Landmark 81,Ho Chi Minh City",
    "Dinh Doc Lap,Ho Chi Minh City",
    "Bitexco Financial Tower,Ho Chi Minh City",
    "San bay quoc te Tan San Nhat,Ho Chi Minh City",
    "Ben Thanh Market,Ho Chi Minh City",
    "Sân vận động Thống Nhất,Ho Chi Minh City",]
geolocator = Nominatim(user_agent="geoapi", timeout=10)
x=[]
y=[]
for i in address:
  location = geolocator.geocode(i)
  if location:
    x.append(location.latitude)
    y.append(location.longitude)
heatdata=[[x[i],y[i]] for i in range(len(x))]

HeatMap(heatdata).add_to(m)
m
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_8143/3049384120.py in <cell line: 0>()
#       2 from geopy.geocoders import Nominatim
#       3 from folium.plugins import HeatMap
# ----> 4 import osmnx as ox
#       5 import networkx as nx
#       6
#
# ModuleNotFoundError: No module named 'osmnx'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

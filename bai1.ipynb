# %% [markdown]
# <a href="https://colab.research.google.com/github/shinowhi/B-i-t-p/blob/main/bai1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import folium
from geopy.geocoders import Nominatim
import osmnx as ox
import networkx as nx
m = folium.Map(location=[10.775, 106.700], zoom_start=13)
folium.Marker([10.7609491, 106.6679786], popup="UEH", tooltip="UEH").add_to(m)
folium.Marker([10.7704843, 106.6695631], popup="Vạn Hạnh Mall", tooltip="Vạn Hạnh Mall").add_to(m)
folium.Marker([10.7566964, 106.6597263], popup="Bệnh viện Chợ Rẫy", tooltip="Bệnh viện Chợ Rẫy").add_to(m)
folium.Marker([10.7679671, 106.6397583], popup="Đầm sen", tooltip="Đầm sen").add_to(m)
folium.Marker([10.7608154, 106.6632871], popup="Sân vận động Thống Nhất", tooltip="Sân vận động Thống Nhất").add_to(m)
m
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_3351/4001405225.py in <cell line: 0>()
#       1 import folium
#       2 from geopy.geocoders import Nominatim
# ----> 3 import osmnx as ox
#       4 import networkx as nx
#       5 m = folium.Map(location=[10.775, 106.700], zoom_start=13)
#
# ModuleNotFoundError: No module named 'osmnx'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
